# %%
from minigrid.core.constants import COLOR_NAMES
from minigrid.core.grid import Grid
from minigrid.core.mission import MissionSpace
from minigrid.core.world_object import Door, Goal, Key, Wall
from minigrid.manual_control import ManualControl
from minigrid.minigrid_env import MiniGridEnv

# %%
class SimpleEnv(MiniGridEnv):
    def __init__(
        self,
        size=10,
        agent_start_pos=(1, 1),
        agent_start_dir=0,
        max_steps: int or None = None,
        **kwargs,
    ):
        self.agent_start_pos = agent_start_pos
        self.agent_start_dir = agent_start_dir

        mission_space = MissionSpace(mission_func=self._gen_mission)

        if max_steps is None:
            max_steps = 4 * size**2

        super().__init__(
            mission_space=mission_space,
            grid_size=size,
            # Set this to True for maximum speed
            see_through_walls=True,
            max_steps=max_steps,
            **kwargs,
        )

    @staticmethod
    def _gen_mission():
        return "grand mission"

    def _gen_grid(self, width, height):
        # Create an empty grid
        self.grid = Grid(width, height)

        # Generate the surrounding walls
        self.grid.wall_rect(0, 0, width, height)

        # Generate vertical separation wall
        for i in range(0, height):
            self.grid.set(5, i, Wall())
        
        # Place the door and key
        self.grid.set(5, 6, Door(COLOR_NAMES[0], is_locked=True))
        self.grid.set(3, 6, Key(COLOR_NAMES[0]))

        # Place a goal square in the bottom-right corner
        self.put_obj(Goal(), width - 2, height - 2)

        # Place the agent
        if self.agent_start_pos is not None:
            self.agent_pos = self.agent_start_pos
            self.agent_dir = self.agent_start_dir
        else:
            self.place_agent()

        self.mission = "grand mission"

# %%
# "left": Actions.left,
# "right": Actions.right,
# "up": Actions.forward,
# "space": Actions.toggle,
# "pageup": Actions.pickup,
# "pagedown": Actions.drop,
# "tab": Actions.pickup,
# "left shift": Actions.drop,
# "enter": Actions.done,

env = SimpleEnv(render_mode="human")

# enable manual control for testing
manual_control = ManualControl(env, seed=42)
# manual_control.start()
# Out:
# pressed right
# step=1, reward=0.00
# pressed up
# step=2, reward=0.00
# pressed up
# step=3, reward=0.00
# pressed up
# step=4, reward=0.00
# pressed up
# step=5, reward=0.00
# pressed escape
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 15
#      13 # enable manual control for testing
#      14 manual_control = ManualControl(env, seed=42)
# ---> 15 manual_control.start()
#
# File ~\anaconda3\envs\mini-grid-generation\lib\site-packages\minigrid\manual_control.py:29, in ManualControl.start(self)
#      26 self.reset(self.seed)
#      28 while not self.closed:
# ---> 29     for event in pygame.event.get():
#      30         if event.type == pygame.QUIT:
#      31             self.env.close()
#
# error: video system not initialized

# %%
import gymnasium as gym
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import torch
import torch.nn as nn
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.8.19)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class MinigridFeaturesExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.Space, features_dim: int = 512, normalized_image: bool = False) -> None:
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 16, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(16, 32, (2, 2)),
            nn.ReLU(),
            nn.Conv2d(32, 64, (2, 2)),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))

# %%
import minigrid
from minigrid.wrappers import ImgObsWrapper
from stable_baselines3 import PPO

# %%
policy_kwargs = dict(
    features_extractor_class=MinigridFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128),
)

env = gym.make("MiniGrid-Empty-16x16-v0", render_mode="rgb_array")
env = ImgObsWrapper(env)

model = PPO("CnnPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(2e5)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 1203     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009470395 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -7.32       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00533     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 2.64e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 855        |
# |    ep_rew_mean          | 0.177      |
# | time/                   |            |
# |    fps                  | 710        |
# |    iterations           | 3          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.03214758 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.9       |
# |    explained_variance   | -8.54      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0247    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0176    |
# |    value_loss           | 9.88e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | 0.138       |
# | time/                   |             |
# |    fps                  | 677         |
# |    iterations           | 4           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011477774 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.00518     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0561      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 0.00373     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 917         |
# |    ep_rew_mean          | 0.113       |
# | time/                   |             |
# |    fps                  | 649         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.032941133 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | -1.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0485      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.000114    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 933         |
# |    ep_rew_mean          | 0.0953      |
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021551846 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -2.78       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.076       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 4.45e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | 0.0826      |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 7           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012663822 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -5.78       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00734     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 5.83e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 949         |
# |    ep_rew_mean          | 0.0838      |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 8           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014000332 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | -7.51       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0219      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00775    |
# |    value_loss           | 2.43e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 957        |
# |    ep_rew_mean          | 0.075      |
# | time/                   |            |
# |    fps                  | 612        |
# |    iterations           | 9          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01564807 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.75      |
# |    explained_variance   | -0.128     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0296     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00976   |
# |    value_loss           | 0.000365   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | 0.0679      |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 10          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.039299924 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | -2.76       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 7.83e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 968         |
# |    ep_rew_mean          | 0.062       |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 11          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010689809 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -3.47       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00725    |
# |    value_loss           | 3.64e-05    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 972       |
# |    ep_rew_mean          | 0.0621    |
# | time/                   |           |
# |    fps                  | 602       |
# |    iterations           | 12        |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0109249 |
# |    clip_fraction        | 0.0761    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.61     |
# |    explained_variance   | -6.08     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.041     |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -0.00624  |
# |    value_loss           | 0.000671  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 966         |
# |    ep_rew_mean          | 0.0699      |
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 13          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.016363773 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | -0.109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 9.57e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 868         |
# |    ep_rew_mean          | 0.17        |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 14          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.028680697 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | -0.101      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00801    |
# |    value_loss           | 0.000606    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 854         |
# |    ep_rew_mean          | 0.187       |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 15          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008424753 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.00909     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.01        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 780         |
# |    ep_rew_mean          | 0.26        |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 16          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015594823 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -0.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 0.00231     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 694         |
# |    ep_rew_mean          | 0.344       |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 17          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010101629 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0492      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 553         |
# |    ep_rew_mean          | 0.479       |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 18          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014189981 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0194      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0146      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00779    |
# |    value_loss           | 0.0164      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 474         |
# |    ep_rew_mean          | 0.555       |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 19          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010673588 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 0.0269      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 339        |
# |    ep_rew_mean          | 0.685      |
# | time/                   |            |
# |    fps                  | 593        |
# |    iterations           | 20         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02007819 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.386      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0215     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 0.0171     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.2        |
# |    ep_rew_mean          | 0.924       |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 21          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.030080672 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.029      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.0235      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.7        |
# |    ep_rew_mean          | 0.951       |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 22          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010585379 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0053      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.0147      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.2        |
# |    ep_rew_mean          | 0.959       |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 23          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009696828 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00968    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.0135      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41           |
# |    ep_rew_mean          | 0.964        |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 24           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0077493573 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.776       |
# |    explained_variance   | 0.586        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0153      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.00712      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.9        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 25          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005654118 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00819    |
# |    value_loss           | 0.00534     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | 0.969       |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 26          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006031542 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00349    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00362     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.3        |
# |    ep_rew_mean          | 0.971       |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 27          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.015301074 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0276     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00892    |
# |    value_loss           | 0.00325     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.4         |
# |    ep_rew_mean          | 0.972        |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 28           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0044314438 |
# |    clip_fraction        | 0.0704       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0177      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00755     |
# |    value_loss           | 0.00343      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.9         |
# |    ep_rew_mean          | 0.973        |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 29           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0038971324 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.309       |
# |    explained_variance   | 0.588        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00114      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00423     |
# |    value_loss           | 0.00335      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.2         |
# |    ep_rew_mean          | 0.973        |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 30           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0014003133 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | 0.633        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00538     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 0.00249      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.2        |
# |    ep_rew_mean          | 0.973       |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 31          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004730327 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00885     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 0.00247     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.1         |
# |    ep_rew_mean          | 0.974        |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 32           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0022346764 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0035       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00351     |
# |    value_loss           | 0.00253      |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50        |
# |    ep_rew_mean          | 0.954     |
# | time/                   |           |
# |    fps                  | 592       |
# |    iterations           | 33        |
# |    time_elapsed         | 114       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.2209921 |
# |    clip_fraction        | 0.0425    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.222    |
# |    explained_variance   | 0.635     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00472  |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.00143  |
# |    value_loss           | 0.00276   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61.6       |
# |    ep_rew_mean          | 0.944      |
# | time/                   |            |
# |    fps                  | 592        |
# |    iterations           | 34         |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.05126692 |
# |    clip_fraction        | 0.277      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | -5.37      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0215    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00135   |
# |    value_loss           | 0.00108    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.8        |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 35          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010516638 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.969      |
# |    explained_variance   | 0.0869      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.0095      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.2        |
# |    ep_rew_mean          | 0.922       |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 36          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009346719 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.815      |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00334    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.0166      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.2        |
# |    ep_rew_mean          | 0.959       |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 37          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008947553 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00134     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 0.0167      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.9        |
# |    ep_rew_mean          | 0.966       |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 38          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008805433 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00285    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 0.0117      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.2       |
# |    ep_rew_mean          | 0.969      |
# | time/                   |            |
# |    fps                  | 592        |
# |    iterations           | 39         |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01244709 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.456     |
# |    explained_variance   | 0.426      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0368    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0152    |
# |    value_loss           | 0.00915    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 31.5       |
# |    ep_rew_mean          | 0.972      |
# | time/                   |            |
# |    fps                  | 592        |
# |    iterations           | 40         |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.01374454 |
# |    clip_fraction        | 0.081      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.322     |
# |    explained_variance   | 0.523      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00273   |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00742   |
# |    value_loss           | 0.00532    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.5         |
# |    ep_rew_mean          | 0.973        |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 41           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0041724974 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.635        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00205      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 0.00325      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 42          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.002680643 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00337    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 0.0028      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.4         |
# |    ep_rew_mean          | 0.974        |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 43           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0021860208 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.157       |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000368     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 0.00252      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.9         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 44           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0018487783 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.128       |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00129      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 0.00247      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.7         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 45           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0031328464 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.625        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00459     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 0.00216      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 46          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.001129766 |
# |    clip_fraction        | 0.0108      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0841     |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00151    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00126    |
# |    value_loss           | 0.00205     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.4         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 47           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0003161932 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0828      |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00114      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000452    |
# |    value_loss           | 0.00207      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.5          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 591           |
# |    iterations           | 48            |
# |    time_elapsed         | 166           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00019964526 |
# |    clip_fraction        | 0.0041        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0905       |
# |    explained_variance   | 0.631         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00117       |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000244     |
# |    value_loss           | 0.00207       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.5          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 591           |
# |    iterations           | 49            |
# |    time_elapsed         | 169           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00054840127 |
# |    clip_fraction        | 0.00884       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.083        |
# |    explained_variance   | 0.639         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00131       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000834     |
# |    value_loss           | 0.00213       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.2          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 591           |
# |    iterations           | 50            |
# |    time_elapsed         | 173           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00086138933 |
# |    clip_fraction        | 0.00908       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0688       |
# |    explained_variance   | 0.641         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00105       |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000925     |
# |    value_loss           | 0.00203       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.3          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 591           |
# |    iterations           | 51            |
# |    time_elapsed         | 176           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00021855894 |
# |    clip_fraction        | 0.00322       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0583       |
# |    explained_variance   | 0.643         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00329      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000539     |
# |    value_loss           | 0.00203       |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.9       |
# |    ep_rew_mean          | 0.961      |
# | time/                   |            |
# |    fps                  | 591        |
# |    iterations           | 52         |
# |    time_elapsed         | 180        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.22201662 |
# |    clip_fraction        | 0.0241     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0591    |
# |    explained_variance   | 0.64       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00191   |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00211   |
# |    value_loss           | 0.00215    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50.6      |
# |    ep_rew_mean          | 0.955     |
# | time/                   |           |
# |    fps                  | 591       |
# |    iterations           | 53        |
# |    time_elapsed         | 183       |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 0.3056277 |
# |    clip_fraction        | 0.209     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.384    |
# |    explained_variance   | 0.164     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0228   |
# |    n_updates            | 520       |
# |    policy_gradient_loss | -0.0099   |
# |    value_loss           | 0.000816  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30.6       |
# |    ep_rew_mean          | 0.973      |
# | time/                   |            |
# |    fps                  | 591        |
# |    iterations           | 54         |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01147111 |
# |    clip_fraction        | 0.0912     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.153     |
# |    explained_variance   | 0.346      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00157   |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.00592   |
# |    value_loss           | 0.0047     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.6         |
# |    ep_rew_mean          | 0.973        |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 55           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0057024276 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.113       |
# |    explained_variance   | 0.612        |
# |    learning_rate        | 0.0003       |
# ...
# | rollout/                |               |
# |    ep_len_mean          | 28.1          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 586           |
# |    iterations           | 81            |
# |    time_elapsed         | 282           |
# |    total_timesteps      | 165888        |
# | train/                  |               |
# |    approx_kl            | 0.00022198365 |
# |    clip_fraction        | 0.00127       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00826      |
# |    explained_variance   | 0.641         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000622      |
# |    n_updates            | 800           |
# |    policy_gradient_loss | -0.000228     |
# |    value_loss           | 0.00195       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28          |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 82          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 8.28277e-05 |
# |    clip_fraction        | 0.000488    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00783    |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00117     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -7.52e-05   |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.1          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 581           |
# |    iterations           | 83            |
# |    time_elapsed         | 292           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 4.1236635e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00906      |
# |    explained_variance   | 0.645         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000721      |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -6.32e-05     |
# |    value_loss           | 0.0021        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.1          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 84            |
# |    time_elapsed         | 296           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.00020154033 |
# |    clip_fraction        | 0.00225       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0103       |
# |    explained_variance   | 0.641         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00133       |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -0.000163     |
# |    value_loss           | 0.00216       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 28.1          |
# |    ep_rew_mean          | 0.975         |
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 85            |
# |    time_elapsed         | 300           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 0.00028133666 |
# |    clip_fraction        | 0.0019        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00867      |
# |    explained_variance   | 0.638         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000904      |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -6.1e-05      |
# |    value_loss           | 0.00205       |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 31.2       |
# |    ep_rew_mean          | 0.973      |
# | time/                   |            |
# |    fps                  | 579        |
# |    iterations           | 86         |
# |    time_elapsed         | 303        |
# |    total_timesteps      | 176128     |
# | train/                  |            |
# |    approx_kl            | 0.02695306 |
# |    clip_fraction        | 0.00454    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0101    |
# |    explained_variance   | 0.64       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0022    |
# |    n_updates            | 850        |
# |    policy_gradient_loss | -0.000407  |
# |    value_loss           | 0.00191    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.9        |
# |    ep_rew_mean          | 0.973       |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 87          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.015321536 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.131      |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.00253     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.8        |
# |    ep_rew_mean          | 0.966       |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 88          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.002922508 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0759     |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0057     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 0.00231     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.9        |
# |    ep_rew_mean          | 0.968       |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 89          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.038092196 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.189      |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0187     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.000601   |
# |    value_loss           | 0.00524     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38.9       |
# |    ep_rew_mean          | 0.966      |
# | time/                   |            |
# |    fps                  | 578        |
# |    iterations           | 90         |
# |    time_elapsed         | 318        |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.03678335 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.342     |
# |    explained_variance   | 0.519      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0174    |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0206    |
# |    value_loss           | 0.00388    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.7        |
# |    ep_rew_mean          | 0.962       |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 91          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.013575435 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.679      |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000907    |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.00537     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.1        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 92          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.006120798 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000867   |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0075     |
# |    value_loss           | 0.00541     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.3        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 93          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.011009811 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.407      |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0207     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.00385     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.9        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 94          |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.043506254 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0337     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 0.005       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 32.9       |
# |    ep_rew_mean          | 0.971      |
# | time/                   |            |
# |    fps                  | 578        |
# |    iterations           | 95         |
# |    time_elapsed         | 336        |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.03875101 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.361     |
# |    explained_variance   | 0.484      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0101    |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0167    |
# |    value_loss           | 0.00362    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31          |
# |    ep_rew_mean          | 0.973       |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 96          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008756054 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00231    |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 0.00309     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.2         |
# |    ep_rew_mean          | 0.973        |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 97           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0023461767 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.22        |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000764     |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 0.00286      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | 0.974        |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 98           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0050316416 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.165       |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0103      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 0.00249      |
# ------------------------------------------
